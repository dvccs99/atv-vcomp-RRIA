# %% [markdown]
# ### HDR
#
# Avalie a influência dos parâmetros do global tone mapping

# %%
import vcomp.hdrtool.hdr as hdr
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
img_1 = plt.imread("dvccs_imgs/gatos.jpg")
plt.imshow(img_1)
plt.axis('off')
plt.tight_layout()
plt.show()

# %%
hdr_mapped = hdr.globalToneMapping(img_1, Lwhite=np.exp(img_1.max())*0.9, alpha=0.3)
hdr_mapped = hdr_mapped.astype(np.uint8)
plt.figure(figsize=(10, 17))
plt.imshow(hdr_mapped)
# Out:
# C:\Users\dvccs\AppData\Local\Temp\ipykernel_22232\4072459318.py:1: RuntimeWarning: overflow encountered in exp
#   hdr_mapped = hdr.globalToneMapping(img_1, Lwhite=np.exp(img_1.max())*0.9, alpha=0.3)
